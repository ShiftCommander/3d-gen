# %%
# Optional automated install step. Set INSTALL = True to execute installs (use with care).
INSTALL = False  # change to True to run installs automatically

commands = [
    'python3 -m pip install --upgrade pip',
    'python3 -m pip install torch==2.0.0 torchvision==0.15.0 --index-url https://download.pytorch.org/whl/cu117',
    'python3 -m pip install -r /kaggle/working/Hunyuan3D-2/requirements.txt',
    'python3 -m pip install diffusers==0.29.2',
    'python3 -m pip install -e /kaggle/working/Hunyuan3D-2',
]

def run(cmd):
    import subprocess, sys
    print('Running:', cmd)
    r = subprocess.run(cmd, shell=True)
    if r.returncode != 0:
        raise RuntimeError(f'Command failed: {cmd}')

if INSTALL:
    print('INSTALL=True — executing pip commands. This may take several minutes.')
    for c in commands:
        run(c)
    print('Automated installs complete. Run the smoke-test cell next.')
else:
    print('INSTALL=False — automated install skipped. To run installs, edit this cell and set INSTALL = True')
    print('\nRecommended commands to run manually:')
    for c in commands: print('  ', c)

print('\nNote: CUDA extension builds are skipped by default; only enable them if your CUDA/PyTorch match.')
